# %%
import numpy as np
from sklearn import datasets
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
iris=datasets.load_iris()
X,y=iris.data, iris.target
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.2, random_state=40)
print(X_train.shape, y_train.shape)
# Out:
# (120, 4) (120,)

# %%
from pca import PCA
pca=PCA(2)
pca.fit(X_train,y_train)

X_train_transformed=pca.transform(X_train)
X_test_transformed=pca.transform(X_test)

# %%
def accuracy(y_preds, y_true):
    return np.sum(y_preds==y_true)/len(y_true)

# %%
model.fit(X_transformed, y_train)
y_preds2=model.predict(X_test_transformed)
print(accuracy(y_preds2, y_test))
# Out:
# 1.0

# %%
x1=X_train_transformed[:,0]
x2=X_train_transformed[:,1]
plt.scatter(x1, x2, c=y_train)

# %%
from sklearn.linear_model import LogisticRegression

model=LogisticRegression()
model.fit(X_train, y_train)
y_preds=model.predict(X_test)

print(accuracy(y_preds, y_test))
# Out:
# 1.0
